# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 21s 2us/step

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
model = keras.Sequential(
    [
        layers.Conv2D(32,(3,3), activation="relu", input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64,(3,3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="sgd",
    metrics=["accuracy"],
)

# %%
history_sgd = model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.5671 - accuracy: 0.8345 - val_loss: 0.1569 - val_accuracy: 0.9563
# Epoch 2/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.1568 - accuracy: 0.9526 - val_loss: 0.0956 - val_accuracy: 0.9728
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.1066 - accuracy: 0.9675 - val_loss: 0.1262 - val_accuracy: 0.9595
# Epoch 4/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0838 - accuracy: 0.9742 - val_loss: 0.0734 - val_accuracy: 0.9795
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0709 - accuracy: 0.9784 - val_loss: 0.0675 - val_accuracy: 0.9810
# Epoch 6/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0616 - accuracy: 0.9811 - val_loss: 0.0605 - val_accuracy: 0.9820
# Epoch 7/10
# 1688/1688 [==============================] - 13s 8ms/step - loss: 0.0549 - accuracy: 0.9833 - val_loss: 0.0612 - val_accuracy: 0.9823
# Epoch 8/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0491 - accuracy: 0.9847 - val_loss: 0.0616 - val_accuracy: 0.9823
# Epoch 9/10
# 1688/1688 [==============================] - 13s 8ms/step - loss: 0.0448 - accuracy: 0.9861 - val_loss: 0.0499 - val_accuracy: 0.9867
# Epoch 10/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0414 - accuracy: 0.9866 - val_loss: 0.0499 - val_accuracy: 0.9867

# %%
model_adam = keras.Sequential(
    [
        layers.Conv2D(32,(3,3), activation="relu", input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64,(3,3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model_adam.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
history_adam = model_adam.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 18s 10ms/step - loss: 0.1392 - accuracy: 0.9574 - val_loss: 0.0482 - val_accuracy: 0.9862
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0451 - accuracy: 0.9858 - val_loss: 0.0404 - val_accuracy: 0.9880
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0377 - val_accuracy: 0.9905
# Epoch 4/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.0386 - val_accuracy: 0.9895
# Epoch 5/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0341 - val_accuracy: 0.9910
# Epoch 6/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.0380 - val_accuracy: 0.9912
# Epoch 7/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0511 - val_accuracy: 0.9880
# Epoch 8/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0477 - val_accuracy: 0.9915
# Epoch 9/10
# 1688/1688 [==============================] - 14s 8ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0549 - val_accuracy: 0.9903
# Epoch 10/10
# 1688/1688 [==============================] - 14s 9ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0416 - val_accuracy: 0.9912

# %%
model_rmsprop = keras.Sequential(
    [
        layers.Conv2D(32,(3,3), activation="relu", input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64,(3,3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model_rmsprop.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"],
)

# %%
history_rmsprop = model_rmsprop.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 20s 11ms/step - loss: 0.1304 - accuracy: 0.9599 - val_loss: 0.0438 - val_accuracy: 0.9880
# Epoch 2/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0443 - accuracy: 0.9861 - val_loss: 0.0376 - val_accuracy: 0.9905
# Epoch 3/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0311 - accuracy: 0.9909 - val_loss: 0.0365 - val_accuracy: 0.9908
# Epoch 4/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.0341 - val_accuracy: 0.9897
# Epoch 5/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0197 - accuracy: 0.9943 - val_loss: 0.0389 - val_accuracy: 0.9890
# Epoch 6/10
# 1688/1688 [==============================] - 16s 10ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 0.0379 - val_accuracy: 0.9920
# Epoch 7/10
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.0145 - accuracy: 0.9962 - val_loss: 0.0485 - val_accuracy: 0.9923
# Epoch 8/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.0497 - val_accuracy: 0.9913
# Epoch 9/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.0620 - val_accuracy: 0.9917
# Epoch 10/10
# 1688/1688 [==============================] - 15s 9ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.0479 - val_accuracy: 0.9930

# %%
plt.plot(history_sgd.history["accuracy"])
plt.plot(history_adam.history["accuracy"])
plt.plot(history_rmsprop.history["accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["SGD", "ADAM", "RMSProp"], loc="upper left")
plt.show()

plt.plot(history_sgd.history["val_accuracy"])
plt.plot(history_adam.history["val_accuracy"])
plt.plot(history_rmsprop.history["val_accuracy"])
plt.title("Model Validation Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["SGD", "ADAM", "RMSProp"], loc="upper left")
plt.show()
