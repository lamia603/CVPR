# %%
import os
import random
import numpy as np 
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt
import math

TRAIN_DIR = '/Users/Sadia/OneDrive/Desktop/CIFAR-10/CIFAR-10/train'
CATEGORIES = []
for c in os.listdir(TRAIN_DIR):
    CATEGORIES.append(c)
print(CATEGORIES)
print(TRAIN_DIR)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# /Users/Sadia/OneDrive/Desktop/CIFAR-10/CIFAR-10/train

# %%
TRAIN_DATA = []
for c in CATEGORIES:
    path = os.path.join(TRAIN_DIR,c)
    class_num = CATEGORIES.index(c)
    for img in tqdm(os.listdir(path)):
        img_arr = cv2.imread(os.path.join(path,img))
        TRAIN_DATA.append([img_arr, class_num])
print(len(TRAIN_DATA))
# Out:
# 100%|██████████| 5000/5000 [00:33<00:00, 148.42it/s]
# 100%|██████████| 5000/5000 [00:32<00:00, 151.86it/s]
# 100%|██████████| 5000/5000 [00:31<00:00, 157.50it/s]
# 100%|██████████| 5000/5000 [00:33<00:00, 150.53it/s]
# 100%|██████████| 5000/5000 [00:31<00:00, 156.29it/s]
# 100%|██████████| 5000/5000 [00:31<00:00, 160.17it/s]
# 100%|██████████| 5000/5000 [00:31<00:00, 157.77it/s]
# 100%|██████████| 5000/5000 [00:32<00:00, 155.29it/s]
# 100%|██████████| 5000/5000 [00:32<00:00, 156.06it/s]
# 100%|██████████| 5000/5000 [00:31<00:00, 159.04it/s]
# 50000

# %%
random.shuffle(TRAIN_DATA)
plt.figure(figsize=(20,10))

for i in range(50):
    plt.subplot(5,10,i+1)
    plt.imshow(TRAIN_DATA[i][0])
    plt.xlabel(CATEGORIES[TRAIN_DATA[i][1]])
    plt.xticks([])
    plt.yticks([])
    if i==50:
        break
plt.show()

# %%
f0 = TRAIN_DATA[:1000]
f1 = TRAIN_DATA[1000:2000]
f2 = TRAIN_DATA[2000:3000]
f3 = TRAIN_DATA[3000:4000]
f4 = TRAIN_DATA[4000:5000]

# %%
k_values = [1, 3, 5, 7, 9]

midpoint_l1_accuracies = []
midpoint_l2_accuracies = []

for i in range(5):
    if i==0:
        train = f1+f2+f3+f4
        validation = f0
    elif i==1:
        train = f0+f2+f3+f4
        validation = f1
    elif i==2:
        train = f0+f1+f3+f4
        validation = f2
    elif i==3:
        train = f0+f1+f2+f4
        validation = f3
    elif i==4:
        train = f0+f1+f2+f3
        validation = f4

    l1_accuracies = []
    l2_accuracies = []
    for k in k_values:
        l1_correct = 0
        l2_correct = 0
        total = 0
        for v in tqdm(validation):
            v_img = v[0]
            v_label = v[1]
            l1_scores = []
            l2_scores = []
            for t in train:
                t_img = t[0]
                t_label = t[1]
                # L1 distance
                l1_dist = np.sum(np.abs(t_img - v_img))
                l1_scores.append((l1_dist, t_label))
                # L2 distance
                l2_dist = np.sqrt(np.sum((t_img - v_img) ** 2))
                l2_scores.append((l2_dist, t_label))
            sorted_l1_scores = sorted(l1_scores, key=lambda x: x[0])[:k]
            l1_neighbors = [s[1] for s in sorted_l1_scores]
            l1_prediction = max(set(l1_neighbors), key=l1_neighbors.count)

            sorted_l2_scores = sorted(l2_scores, key=lambda x: x[0])[:k]
            l2_neighbors = [s[1] for s in sorted_l2_scores]
            l2_prediction = max(set(l2_neighbors), key=l2_neighbors.count)
            if l1_prediction == v_label:
                l1_correct += 1
            if l2_prediction == v_label:
                l2_correct += 1

            total += 1

        l1_accuracy = l1_correct / total
        l1_accuracies.append(l1_accuracy)

        l2_accuracy = l2_correct / total
        l2_accuracies.append(l2_accuracy)

        print("Fold {}, k = {}, L1 accuracy = {:.2f}%, L2 accuracy = {:.2f}%".format(i, k, l1_accuracy * 100, l2_accuracy * 100))

    min_l1_accuracy = min(l1_accuracies)
    max_l1_accuracy = max(l1_accuracies)
    midpoint_l1_accuracy = (min_l1_accuracy + max_l1_accuracy) / 2
    midpoint_l1_accuracies.append(midpoint_l1_accuracy)

    min_l2_accuracy = min(l2_accuracies)
    max_l2_accuracy = max(l2_accuracies)
    midpoint_l2_accuracy = (min_l2_accuracy + max_l2_accuracy) / 2
    midpoint_l2_accuracies.append(midpoint_l2_accuracy)

    print("Midpoint L1 accuracy for Fold {} = {:.2f}%, Midpoint L2 accuracy for Fold {} = {:.2f}%".format(i, midpoint_l1_accuracy * 100, i, midpoint_l2_accuracy * 100))
# Plotting the graph
plt.plot(k_values, midpoint_l1_accuracies, label='L1 distance')
plt.plot(k_values, midpoint_l2_accuracies, label='L2 distance')
plt.xlabel('k')
plt.ylabel('Midpoint accuracy')
plt.title('KNN performance on CIFAR-10')
plt.legend()
plt.show()
# Out:
# 100%|██████████| 1000/1000 [01:43<00:00,  9.63it/s]
# Fold 0, k = 1, L1 accuracy = 23.80%, L2 accuracy = 20.10%
# 100%|██████████| 1000/1000 [01:42<00:00,  9.79it/s]
# Fold 0, k = 3, L1 accuracy = 19.50%, L2 accuracy = 20.30%
# 100%|██████████| 1000/1000 [01:45<00:00,  9.44it/s]
# Fold 0, k = 5, L1 accuracy = 21.60%, L2 accuracy = 19.50%
# 100%|██████████| 1000/1000 [01:45<00:00,  9.52it/s]
# Fold 0, k = 7, L1 accuracy = 20.80%, L2 accuracy = 19.70%
# 100%|██████████| 1000/1000 [01:44<00:00,  9.60it/s]
# Fold 0, k = 9, L1 accuracy = 21.00%, L2 accuracy = 19.90%
# Midpoint L1 accuracy for Fold 0 = 21.65%, Midpoint L2 accuracy for Fold 0 = 19.90%
# 100%|██████████| 1000/1000 [01:45<00:00,  9.47it/s]
# Fold 1, k = 1, L1 accuracy = 21.10%, L2 accuracy = 22.50%
# 100%|██████████| 1000/1000 [01:48<00:00,  9.18it/s]
# Fold 1, k = 3, L1 accuracy = 20.50%, L2 accuracy = 19.30%
# 100%|██████████| 1000/1000 [01:52<00:00,  8.88it/s]
# Fold 1, k = 5, L1 accuracy = 21.00%, L2 accuracy = 22.00%
# 100%|██████████| 1000/1000 [02:00<00:00,  8.33it/s]
# Fold 1, k = 7, L1 accuracy = 19.70%, L2 accuracy = 20.30%
# 100%|██████████| 1000/1000 [01:54<00:00,  8.76it/s]
# Fold 1, k = 9, L1 accuracy = 20.20%, L2 accuracy = 20.80%
# Midpoint L1 accuracy for Fold 1 = 20.40%, Midpoint L2 accuracy for Fold 1 = 20.90%
# 100%|██████████| 1000/1000 [01:56<00:00,  8.59it/s]
# Fold 2, k = 1, L1 accuracy = 20.70%, L2 accuracy = 21.90%
# 100%|██████████| 1000/1000 [01:55<00:00,  8.68it/s]
# Fold 2, k = 3, L1 accuracy = 20.20%, L2 accuracy = 19.50%
# 100%|██████████| 1000/1000 [01:53<00:00,  8.79it/s]
# Fold 2, k = 5, L1 accuracy = 20.60%, L2 accuracy = 21.50%
# 100%|██████████| 1000/1000 [01:52<00:00,  8.86it/s]
# Fold 2, k = 7, L1 accuracy = 19.10%, L2 accuracy = 22.60%
# 100%|██████████| 1000/1000 [01:58<00:00,  8.47it/s]
# Fold 2, k = 9, L1 accuracy = 19.50%, L2 accuracy = 23.90%
# Midpoint L1 accuracy for Fold 2 = 19.90%, Midpoint L2 accuracy for Fold 2 = 21.70%
# 100%|██████████| 1000/1000 [01:53<00:00,  8.80it/s]
# Fold 3, k = 1, L1 accuracy = 21.40%, L2 accuracy = 16.90%
# 100%|██████████| 1000/1000 [01:55<00:00,  8.68it/s]
# Fold 3, k = 3, L1 accuracy = 21.20%, L2 accuracy = 16.20%
# 100%|██████████| 1000/1000 [01:53<00:00,  8.81it/s]
# Fold 3, k = 5, L1 accuracy = 19.90%, L2 accuracy = 17.30%
# 100%|██████████| 1000/1000 [02:00<00:00,  8.28it/s]
# Fold 3, k = 7, L1 accuracy = 20.70%, L2 accuracy = 19.00%
# 100%|██████████| 1000/1000 [01:56<00:00,  8.60it/s]
# Fold 3, k = 9, L1 accuracy = 19.80%, L2 accuracy = 18.70%
# Midpoint L1 accuracy for Fold 3 = 20.60%, Midpoint L2 accuracy for Fold 3 = 17.60%
# 100%|██████████| 1000/1000 [01:57<00:00,  8.48it/s]
# Fold 4, k = 1, L1 accuracy = 21.60%, L2 accuracy = 18.60%
# 100%|██████████| 1000/1000 [01:56<00:00,  8.56it/s]
# Fold 4, k = 3, L1 accuracy = 19.80%, L2 accuracy = 18.30%
# 100%|██████████| 1000/1000 [01:56<00:00,  8.58it/s]
# Fold 4, k = 5, L1 accuracy = 20.30%, L2 accuracy = 17.30%
# 100%|██████████| 1000/1000 [01:57<00:00,  8.49it/s]
# Fold 4, k = 7, L1 accuracy = 18.80%, L2 accuracy = 17.20%
# 100%|██████████| 1000/1000 [01:55<00:00,  8.69it/s]
# Fold 4, k = 9, L1 accuracy = 19.30%, L2 accuracy = 17.60%
# Midpoint L1 accuracy for Fold 4 = 20.20%, Midpoint L2 accuracy for Fold 4 = 17.90%
